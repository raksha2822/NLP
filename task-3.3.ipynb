# %% [markdown]
# #                                           Explore COCA

# %% [markdown]
# <div style="font-size: 20px">
# Demonstrate any three of the five features.
# </div>

# %% [markdown]
# <div style="font-size: 20px">
# 1. Find the frequency count of a word
# </div>

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# <div style="font-size: 20px">
# 2. Chart - word - frequency; section; sub-section; year
#     </div>

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# <div style="font-size: 20px">
# 3. Collocate - Display three collocations on the left and right of the word
#     </div>

# %% [markdown]
# ![4.png](attachment:4.png)
